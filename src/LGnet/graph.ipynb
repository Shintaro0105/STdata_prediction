# %%
import matplotlib.pyplot as plt

# Data
memory_sizes = [64, 32, 16, 8]
L1_means = [2.8202857860131707, 2.7678612171633667, 2.8118702639164006, 3.3000178237430835]
L1_stds = [0.15049534414605742, 0.134781531882783, 0.10668757075129601, 0.23349361266473556]
MAEs = [2.8202857860131707, 2.7678612171633667, 2.8118702639164006, 3.3000178237430835]
MAPEs = [6.939008831977844, 6.905046105384827, 6.991849839687347, 8.829566836357117]

# Plotting
plt.figure(figsize=(10, 6))

plt.plot(memory_sizes, L1_means, marker='o', linestyle='-', label='L1_mean', color='b')
plt.plot(memory_sizes, L1_stds, marker='o', linestyle='-', label='L1_std', color='r')
plt.plot(memory_sizes, MAEs, marker='o', linestyle='-', label='MAE', color='g')
plt.plot(memory_sizes, MAPEs, marker='o', linestyle='-', label='MAPE', color='m')

plt.title('Metrics vs Memory Size')
plt.xlabel('Memory Size')
plt.ylabel('Metrics Value')
plt.legend()
plt.grid(True)
plt.gca().invert_xaxis()  # Memory size in decreasing order

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
memory_sizes = [64, 32, 16, 8]
L1_means = [2.8202857860131707, 2.7678612171633667, 2.8118702639164006, 3.3000178237430835]
L1_stds = [0.15049534414605742, 0.134781531882783, 0.10668757075129601, 0.23349361266473556]
MAEs = [2.8202857860131707, 2.7678612171633667, 2.8118702639164006, 3.3000178237430835]
MAPEs = [6.939008831977844, 6.905046105384827, 6.991849839687347, 8.829566836357117]

# Plotting
plt.figure(figsize=(10, 6))

plt.plot(memory_sizes, L1_means, marker='o', linestyle='-', label='L1_mean', color='b')
plt.plot(memory_sizes, L1_stds, marker='o', linestyle='-', label='L1_std', color='r')
plt.plot(memory_sizes, MAEs, marker='o', linestyle='-', label='MAE', color='g')
plt.plot(memory_sizes, MAPEs, marker='o', linestyle='-', label='MAPE', color='m')

plt.xscale('log')
plt.gca().invert_xaxis()  # Reverse the x-axis to show smaller values first

plt.title('Metrics vs Memory Size')
plt.xlabel('Memory Size (log scale)')
plt.ylabel('Metrics Value')
plt.legend()
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# Data
memory_sizes = [8, 16, 32, 64, 128]
L1_means = [2.846059080098215, 2.8256121617280487, 2.730358683083033, 2.7630036837375878, 2.7840818874912014]
L1_stds = [0.15603349633205982, 0.1180667985358904, 0.19430718998313282, 0.11146931886685006, 0.1580200905176089]
MAEs = [2.846059080098215, 2.8256121617280487, 2.730358683083033, 2.7630036837375878, 2.7840818874912014]
MAPEs = [6.919250637292862, 6.987116485834122, 6.705082952976227, 6.509561836719513, 6.661637127399445]

# Plotting
plt.figure(figsize=(10, 6))

plt.plot(memory_sizes, L1_means, marker='o', linestyle='-', label='L1_mean', color='b')
plt.plot(memory_sizes, L1_stds, marker='o', linestyle='-', label='L1_std', color='r')
plt.plot(memory_sizes, MAEs, marker='o', linestyle='-', label='MAE', color='g')
plt.plot(memory_sizes, MAPEs, marker='o', linestyle='-', label='MAPE', color='m')

plt.xscale('log', base=2)

plt.title('Metrics vs Memory Size')
plt.xlabel('Memory Size (log scale)')
plt.ylabel('Metrics Value')
plt.legend()
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
lambdas = [0.0, 0.1, 1.0, 10.0, 100.0]
L1_means = [2.819989691044554, 2.9553169112558217, 2.9434352293268438, 2.7344100623465604, 2.8149381957150754]
L1_stds = [0.13871926159336107, 0.1590287208292355, 0.1170602139162169, 0.1064977854686672, 0.18585270503129353]
MAEs = [2.819989691044554, 2.9553169112558217, 2.9434352293268438, 2.7344100623465604, 2.8149381957150754]
MAPEs = [6.83436393737793, 7.0178404450416565, 6.836076080799103, 6.499790400266647, 6.877104938030243]

# Prepare the data for plotting with a log scale
plot_lambdas = [1e-2] + lambdas[1:]  # Replace 0 with a small value

# Plotting
plt.figure(figsize=(10, 6))

plt.plot(plot_lambdas, L1_means, marker='o', linestyle='-', label='L1_mean', color='b')
plt.plot(plot_lambdas, L1_stds, marker='o', linestyle='-', label='L1_std', color='r')
plt.plot(plot_lambdas, MAEs, marker='o', linestyle='-', label='MAE', color='g')
plt.plot(plot_lambdas, MAPEs, marker='o', linestyle='-', label='MAPE', color='m')

plt.xscale('log')

# Custom x-ticks to include 0
plt.xticks([1e-2, 0.1, 1.0, 10, 100], ['0', '0.1', '1', '10', '100'])

plt.title('Metrics vs Lambda')
plt.xlabel('Lambda (log scale)')
plt.ylabel('Metrics Value')
plt.legend()
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

lambdas = [0.0, 0.1, 1.0, 10.0, 100.0]
# Data
data = {
    'memory_size': [8, 8, 8, 8, 8, 16, 16, 16, 16, 16, 32, 32, 32, 32, 32, 64, 64, 64, 64, 64, 128, 128, 128, 128, 128],
    'lambda_dis': [0.0, 0.1, 1.0, 10.0, 100.0, 0.0, 0.1, 1.0, 10.0, 100.0, 0.0, 0.1, 1.0, 10.0, 100.0, 0.0, 0.1, 1.0, 10.0, 100.0, 0.0, 0.1, 1.0, 10.0, 100.0],
    'L1_mean': [2.7989875567250473, 2.8474859123523055, 3.0450333836811603, 2.896839821814164, 2.8662971863564293, 3.0093062071506282, 2.738370521967728, 2.8460336225983545, 2.835023860039601, 2.8318434909498755, 2.7691704600133393, 2.801059009243465, 2.7917003473899555, 2.742351590041164, 2.774361365461102, 2.7425625236114373, 2.7483444067345353, 2.7118365335416117, 2.6996796681617594, 2.7457919893080374, 2.7117965288989736, 2.696922075409004, 2.6560664249184627, 2.7668983781507825, 2.7525151937950274],
    'L1_std': [0.12663778375029852, 0.15957175733481813, 0.20659751782133137, 0.14998804095408116, 0.1578349743374471, 0.17838721743080888, 0.18593080121576167, 0.13556977676964926, 0.17752709867249844, 0.16750534850230767, 0.151771022494726, 0.15293000169410806, 0.12542791796358352, 0.12576604432519906, 0.11503195769871592, 0.14446830946645256, 0.13563692471384997, 0.15332596620737857, 0.12289160089041998, 0.15838983039653642, 0.16513509236759483, 0.11235110680658944, 0.125357919309763, 0.13914392261875122, 0.15648989399511098],
    'MAE': [2.7989875567250473, 2.8474859123523055, 3.0450333836811603, 2.896839821814164, 2.8662971863564293, 3.0093062071506282, 2.738370521967728, 2.8460336225983545, 2.835023860039601, 2.8318434909498755, 2.7691704600133393, 2.801059009243465, 2.7917003473899555, 2.742351590041164, 2.774361365461102, 2.7425625236114373, 2.7483444067345353, 2.7118365335416117, 2.6996796681617594, 2.7457919893080374, 2.7117965288989736, 2.696922075409004, 2.6560664249184627, 2.7668983781507825, 2.7525151937950274],
    'MAPE': [6.884514540433884, 6.9406017661094666, 7.761944085359573, 7.210290431976318, 7.193546742200851, 7.353758811950684, 6.7339107394218445, 6.713545322418213, 7.076019048690796, 6.7754290997982025, 6.871793419122696, 6.807752698659897, 6.679088622331619, 6.627607345581055, 6.6501714289188385, 6.762658059597015, 6.525091081857681, 6.5359726548194885, 6.429120898246765, 6.621157377958298, 6.509244441986084, 6.463999301195145, 6.432536989450455, 6.664819270372391, 6.580273061990738]
}

# Prepare the data for plotting with a log scale
plot_lambdas = [1e-2] + lambdas[1:]  # Replace 0 with a small value

# Convert to DataFrame
df = pd.DataFrame(data)

# Plotting
plt.figure(figsize=(12, 8))

for memory_size in sorted(df['memory_size'].unique()):
    subset = df[df['memory_size'] == memory_size]
    plt.plot(plot_lambdas, subset['L1_mean'], marker='o', linestyle='-', label=f'L1_mean (memory_size={memory_size})')
    plt.plot(plot_lambdas, subset['L1_std'], marker='o', linestyle='--', label=f'L1_std (memory_size={memory_size})')
    plt.plot(plot_lambdas, subset['MAE'], marker='x', linestyle='-.', label=f'MAE (memory_size={memory_size})')
    plt.plot(plot_lambdas, subset['MAPE'], marker='s', linestyle=':', label=f'MAPE (memory_size={memory_size})')

plt.xscale('log')

# Add custom ticks for lambda_dis including 0
lambda_ticks = sorted(df['lambda_dis'].unique())
plt.xticks([1e-2, 0.1, 1.0, 10, 100], ['0', '0.1', '1', '10', '100'])

plt.title('Metrics vs Lambda_dis for Different Memory Sizes')
plt.xlabel('Lambda_dis (log scale)')
plt.ylabel('Metrics Value')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data = '/workspaces/STdata_prediction/src/LGnet/output/grid_search_results_BAY_8_gl_unmask.csv'

df = pd.read_csv(data)

# lambdasの値を取得し、0.0を小さな値に置き換え
lambdas = [0.0, 0.1, 1.0, 10.0, 100.0]
plot_lambdas = [1e-2] + lambdas[1:]  # 0を小さな値に置き換え

# プロットの準備
plt.figure(figsize=(12, 8))

# memory_sizeごとにプロット
for memory_size in sorted(df['memory_size'].unique()):
    subset = df[df['memory_size'] == memory_size]
    #plt.plot(plot_lambdas, subset['L1_mean'], marker='o', linestyle='-', label=f'L1_mean (memory_size={memory_size})')
    #plt.plot(plot_lambdas, subset['L1_std'], marker='o', linestyle='--', label=f'L1_std (memory_size={memory_size})')
    #plt.plot(plot_lambdas, subset['MAE'], marker='x', linestyle='-.', label=f'MAE (memory_size={memory_size})')
    plt.plot(plot_lambdas, subset['MAPE'], marker='s', linestyle=':', label=f'MAPE (memory_size={memory_size})')

# x軸を対数スケールに設定
plt.xscale('log')

# lambda_disのカスタムティックを追加
lambda_ticks = sorted(df['lambda_dis'].unique())
plt.xticks([1e-2, 0.1, 1.0, 10, 100], ['0', '0.1', '1', '10', '100'])

# プロットのタイトルとラベルを設定
plt.title('Metrics vs Lambda_dis for Different Memory Sizes')
plt.xlabel('Lambda_dis (log scale)')
plt.ylabel('Metrics Value')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)

# プロットを表示
plt.show()

# %%
# Load data from CSV
file_path = '/workspaces/STdata_prediction/src/LGnet/output/grid_search_results_adv_pre_BAY_8.csv'  # Replace with your file path
data = pd.read_csv(file_path)

# Extract columns
memory_sizes = data['memory_size']
L1_means = data['L1_mean']
L1_stds = data['L1_std']
MAEs = data['MAE']
MAPEs = data['MAPE']

# Plot each metric against Mask_Rate
plt.figure(figsize=(10, 8))

# Plot L1_mean
plt.subplot(2, 2, 1)
plt.plot(memory_sizes, L1_means, marker='o', linestyle='-', label='L1_mean', color='b')
plt.title('L1_mean vs Memory Size')
plt.xlabel('Memory Size (log scale)')
plt.ylabel('L1_mean')
plt.xscale('log', base=2)
plt.grid(True)

# Plot L1_std
plt.subplot(2, 2, 2)
plt.plot(memory_sizes, L1_stds, marker='o', linestyle='-', label='L1_std', color='r')
plt.title('L1_std vs Memory Size')
plt.xlabel('Memory Size (log scale)')
plt.ylabel('L1_std')
plt.xscale('log', base=2)
plt.grid(True)

# Plot MAE
plt.subplot(2, 2, 3)
plt.plot(memory_sizes, MAEs, marker='o', linestyle='-', label='MAE', color='g')
plt.title('MAE vs Memory Size')
plt.xlabel('Memory Size (log scale)')
plt.ylabel('MAE')
plt.xscale('log', base=2)
plt.grid(True)

# Plot MAPE
plt.subplot(2, 2, 4)
plt.plot(memory_sizes, MAPEs, marker='o', linestyle='-', label='MAPE', color='m')
plt.title('MAPE vs Memory Size')
plt.xlabel('Memory Size (log scale)')
plt.ylabel('MAPE')
plt.xscale('log', base=2)
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 # Load data from CSV
#       2 file_path = '/workspaces/STdata_prediction/src/LGnet/output/grid_search_results_adv_pre_BAY_8.csv'  # Replace with your file path
# ----> 3 data = pd.read_csv(file_path)
#       5 # Extract columns
#       6 memory_sizes = data['memory_size']
#
# ...

# %%
# Load data from CSV
file_path = '/workspaces/STdata_prediction/src/LGnet/output/grid_search_results_mem_pre_BAY_64_gl_unmask.csv'  # Replace with your file path
data = pd.read_csv(file_path)

# Extract columns
lambdas = data['lambda_dis']
L1_means = data['L1_mean']
L1_stds = data['L1_std']
MAEs = data['MAE']
MAPEs = data['MAPE']

# Prepare the data for plotting with a log scale
plot_lambdas = lambdas.copy()
plot_lambdas.iloc[0] = 1e-2  # Replace 0 with a small value for log scale plotting

# Plot each metric against Mask_Rate
plt.figure(figsize=(10, 8))

# Plot L1_mean
plt.subplot(2, 2, 1)
plt.plot(plot_lambdas, L1_means, marker='o', linestyle='-', label='L1_mean', color='b')
plt.title('L1_mean vs Lambda')
plt.xlabel('Lambda (log scale)')
plt.ylabel('L1_mean')
# Custom x-ticks to include 0
plt.xticks([1e-2, 0.1, 1.0, 10, 100], ['0', '0.1', '1', '10', '100'])
plt.xscale('log')
plt.grid(True)

# Plot L1_std
plt.subplot(2, 2, 2)
plt.plot(plot_lambdas, L1_stds, marker='o', linestyle='-', label='L1_std', color='r')
plt.title('L1_std vs Lambda')
plt.xlabel('Lambda (log scale)')
plt.ylabel('L1_std')
# Custom x-ticks to include 0
plt.xticks([1e-2, 0.1, 1.0, 10, 100], ['0', '0.1', '1', '10', '100'])
plt.xscale('log')
plt.grid(True)

# Plot MAE
plt.subplot(2, 2, 3)
plt.plot(plot_lambdas, MAEs, marker='o', linestyle='-', label='MAE', color='g')
plt.title('MAE vs Lambda')
plt.xlabel('Lambda (log scale)')
plt.ylabel('MAE')
# Custom x-ticks to include 0
plt.xticks([1e-2, 0.1, 1.0, 10, 100], ['0', '0.1', '1', '10', '100'])
plt.xscale('log')
plt.grid(True)

# Plot MAPE
plt.subplot(2, 2, 4)
plt.plot(plot_lambdas, MAPEs, marker='o', linestyle='-', label='MAPE', color='m')
plt.title('MAPE vs Lambda')
plt.xlabel('Lambda (log scale)')
plt.ylabel('MAPE')
# Custom x-ticks to include 0
plt.xticks([1e-2, 0.1, 1.0, 10, 100], ['0', '0.1', '1', '10', '100'])
plt.xscale('log')
plt.grid(True)

plt.tight_layout()
plt.show()

#plt.plot(plot_lambdas, L1_means, marker='o', linestyle='-', label='L1_mean', color='b')
#plt.plot(plot_lambdas, L1_stds, marker='o', linestyle='-', label='L1_std', color='r')
#plt.plot(plot_lambdas, MAEs, marker='o', linestyle='-', label='MAE', color='g')
#plt.plot(plot_lambdas, MAPEs, marker='o', linestyle='-', label='MAPE', color='m')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Load data from CSV
#       2 file_path = '/workspaces/STdata_prediction/src/LGnet/output/grid_search_results_mem_pre_BAY_64_gl_unmask.csv'  # Replace with your file path
# ----> 3 data = pd.read_csv(file_path)
#       5 # Extract columns
#       6 lambdas = data['lambda_dis']
#
# NameError: name 'pd' is not defined

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data = '/workspaces/STdata_prediction/src/LGnet/output/missrate_BAY_8_64_100.csv'
data_advmem = '/workspaces/STdata_prediction/src/LGnet/output/missrate_advmem_BAY_8_8_01.csv'
data_grud = '/workspaces/STdata_prediction/src/GRU-D-zhiyongc/output/missrate_BAY_8_GRUD.csv'
data_st = '/workspaces/STdata_prediction/src/ST-graph/output/main_bay_missrate.csv'

df = pd.read_csv(data)
df_ = pd.read_csv(data_advmem)
df__ = pd.read_csv(data_grud)
df___ = pd.read_csv(data_st)

# Plot each metric against Mask_Rate
plt.figure(figsize=(10, 8))

# Plot L1_mean
plt.subplot(2, 2, 1)
plt.plot(df['Mask_Rate'], df['L1_mean'], marker='o', label='LGnet', color='b')
plt.plot(df_['Mask_Rate'], df_['L1_mean'], marker='o', label='LGnet_advmem', color='r')
plt.plot(df__['Mask_Rate'], df__['L1_mean'], marker='o', label='GRUD', color='g')
plt.plot(df___['Mask_Rate'], df___['L1_mean'], marker='o', label='ST', color='m')
plt.title('L1_mean')
plt.xlabel('Mask_Rate')
plt.ylabel('L1_mean')
plt.grid(True)
plt.legend()

# Plot L1_std
plt.subplot(2, 2, 2)
plt.plot(df['Mask_Rate'], df['L1_std'], marker='o', label='LGnet', color='b')
plt.plot(df_['Mask_Rate'], df_['L1_std'], marker='o', label='LGnet_advmem', color='r')
plt.plot(df__['Mask_Rate'], df__['L1_std'], marker='o', label='GRUD', color='g')
plt.plot(df___['Mask_Rate'], df___['L1_std'], marker='o', label='ST', color='m')
plt.title('L1_std')
plt.xlabel('Mask_Rate')
plt.ylabel('L1_std')
plt.grid(True)
plt.legend()

# Plot MAE
plt.subplot(2, 2, 3)
plt.plot(df['Mask_Rate'], df['MAE'], marker='o', label='LGnet', color='b')
plt.plot(df_['Mask_Rate'], df_['MAE'], marker='o', label='LGnet_advmem', color='r')
plt.plot(df__['Mask_Rate'], df__['MAE'], marker='o', label='GRUD', color='g')
plt.plot(df___['Mask_Rate'], df___['MAE'], marker='o', label='ST', color='m')
plt.title('MAE')
plt.xlabel('Mask_Rate')
plt.ylabel('MAE')
plt.grid(True)
plt.legend()

# Plot MAPE
plt.subplot(2, 2, 4)
plt.plot(df['Mask_Rate'], df['MAPE'], marker='o', label='LGnet', color='b')
plt.plot(df_['Mask_Rate'], df_['MAPE'], marker='o', label='LGnet_advmem', color='r')
plt.plot(df__['Mask_Rate'], df__['MAPE'], marker='o', label='GRUD', color='g')
plt.plot(df___['Mask_Rate'], df___['MAPE'], marker='o', label='ST', color='m')
plt.title('MAPE')
plt.xlabel('Mask_Rate')
plt.ylabel('MAPE')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
plt.plot(df['Mask_Rate'], df['MAE'], marker='o', label='LGnet', color='b')
plt.plot(df__['Mask_Rate'], df__['MAE'], marker='o', label='GRUD', color='g')
plt.plot(df___['Mask_Rate'], df___['MAE'], marker='o', label='Proposed Method', color='m')
plt.title('MAE',fontsize=20)
plt.xlabel('Mask Rate',fontsize=18)
plt.ylabel('MAE',fontsize=18)
plt.grid(True)
plt.legend()

# %%
plt.plot(df['Mask_Rate'], df['MAPE'], marker='o', label='LGnet', color='b')
plt.plot(df__['Mask_Rate'], df__['MAPE'], marker='o', label='GRUD', color='g')
plt.plot(df___['Mask_Rate'], df___['MAPE'], marker='o', label='Proposed Method', color='m')
plt.title('MAPE',fontsize=20)
plt.xlabel('Mask Rate',fontsize=18)
plt.ylabel('MAPE',fontsize=18)
plt.grid(True)
plt.legend()
