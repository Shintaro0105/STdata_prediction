# %%
import time

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.utils.data as utils
from Discriminator import *
from LGnet import *


def wasserstein_loss(y_pred, y_true):
    return torch.mean(y_pred * y_true)

def plot_heatmap(s_i, epoch):
    s_i_np = s_i.cpu().detach().numpy()
    plt.figure(figsize=(10, 5))
    plt.imshow(s_i_np, aspect='auto', cmap='viridis')
    plt.colorbar()
    plt.title(f's_i content at epoch {epoch}')
    plt.xlabel('Memory Size')
    plt.ylabel('Batch Size')
    plt.show()

def plot_memorymap(memory, epoch):
    memory_np = memory.cpu().detach().numpy()
    plt.figure(figsize=(10, 5))
    plt.imshow(memory_np, aspect='auto', cmap='viridis')
    plt.colorbar()
    plt.title(f'memory content at epoch {epoch}')
    plt.xlabel('Memory Dim')
    plt.ylabel('Memoey Size')
    plt.show()

def plot_losses_combined(losses_train, losses_valid, losses_d_real, losses_d_fake, filename):
    plt.figure(figsize=(10, 6))

    plt.plot(losses_train, label="Training Loss")
    plt.plot(losses_valid, label="Validation Loss")
    plt.plot(losses_d_real, label="Discriminator Real Loss")
    plt.plot(losses_d_fake, label="Discriminator Fake Loss")

    plt.title("Losses Over Epochs")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)

    plt.savefig(filename)
    plt.show()


def PrepareDataset(
    speed_matrix,
    BATCH_SIZE=40,
    seq_len=10,
    pred_len=1,
    train_propotion=0.7,
    valid_propotion=0.2,
    masking=False,
    mask_ones_proportion=0.8,
):
    """Prepare training and testing datasets and dataloaders.

    Convert speed/volume/occupancy matrix to training and testing dataset.
    The vertical axis of speed_matrix is the time axis and the horizontal axis
    is the spatial axis.

    Args:
        speed_matrix: a Matrix containing spatial-temporal speed data for a network
        seq_len: length of input sequence
        pred_len: length of predicted sequence
    Returns:
        Training dataloader
        Testing dataloader
    """

    speed_matrix_s = np.split(speed_matrix, 16)
    speed_matrix = speed_matrix_s[0]
    time_len = speed_matrix.shape[0]
    print("Time len: ", time_len)

    speed_matrix = speed_matrix.clip(0, 100)

    max_speed = speed_matrix.max().max()
    speed_matrix = speed_matrix / max_speed

    speed_sequences, speed_labels = [], []
    for i in range(time_len - seq_len - pred_len):
        speed_sequences.append(speed_matrix.iloc[i : i + seq_len].values)
        speed_labels.append(speed_matrix.iloc[i + seq_len : i + seq_len + pred_len].values)
    speed_sequences, speed_labels = np.asarray(speed_sequences), np.asarray(speed_labels)

    # using zero-one mask to randomly set elements to zeros
    if masking:
        print("Split Speed finished. Start to generate Mask, Delta, Last_observed_X ...")
        np.random.seed(1024)
        Mask = np.random.choice(
            [0, 1], size=(speed_sequences.shape), p=[1 - mask_ones_proportion, mask_ones_proportion]
        )
        speed_sequences = np.multiply(speed_sequences, Mask)

        # temporal information
        interval = 5  # 5 minutes
        S = np.zeros_like(speed_sequences)  # time stamps
        for i in range(S.shape[1]):
            S[:, i, :] = interval * i

        Delta = np.zeros_like(speed_sequences)  # time intervals
        for i in range(1, S.shape[1]):
            Delta[:, i, :] = S[:, i, :] - S[:, i - 1, :]

        # Calculate Delta_b (backward direction)
        Delta_b = np.zeros_like(speed_sequences)
        for i in range(0, S.shape[1] - 1):
            Delta_b[:, i, :] = S[:, i + 1, :] - S[:, i, :]

        missing_index = np.where(Mask == 0)

        X_last_obsv = np.copy(speed_sequences)
        X_last_obsv_b = np.copy(speed_sequences)
        for idx in range(missing_index[0].shape[0]):
            i = missing_index[0][idx]
            j = missing_index[1][idx]
            k = missing_index[2][idx]
            if j != 0 and j != 9:
                Delta[i, j + 1, k] = Delta[i, j + 1, k] + Delta[i, j, k]
            if j != 0:
                X_last_obsv[i, j, k] = X_last_obsv[i, j - 1, k]  # last observation

        Delta = Delta / Delta.max()  # normalize

        for idx in range(missing_index[0].shape[0], -1):
            i = missing_index[0][idx]
            j = missing_index[1][idx]
            k = missing_index[2][idx]
            if j != 0 and j != 9:
                Delta_b[i, j - 1, k] += Delta_b[i, j, k] + Delta_b[i, j - 1, k]
            if j != 9:
                X_last_obsv_b[i, j, k] = X_last_obsv_b[i, j + 1, k]

        Delta_b = Delta_b / Delta_b.max()  # normalize

    # shuffle and split the dataset to training and testing datasets
    print("Generate Mask, Delta, Last_observed_X finished. Start to shuffle and split dataset ...")
    sample_size = speed_sequences.shape[0]
    index = np.arange(sample_size, dtype=int)
    np.random.seed(1024)
    np.random.shuffle(index)

    speed_sequences = speed_sequences[index]
    speed_labels = speed_labels[index]

    if masking:
        X_last_obsv = X_last_obsv[index]
        Mask = Mask[index]
        Delta = Delta[index]
        X_last_obsv_b = X_last_obsv_b[index]
        Delta_b = Delta_b[index]

        speed_sequences = np.expand_dims(speed_sequences, axis=1)
        X_last_obsv = np.expand_dims(X_last_obsv, axis=1)
        Mask = np.expand_dims(Mask, axis=1)
        Delta = np.expand_dims(Delta, axis=1)
        X_last_obsv_b = np.expand_dims(X_last_obsv_b, axis=1)
        Delta_b = np.expand_dims(Delta_b, axis=1)

        dataset_agger = np.concatenate((speed_sequences, X_last_obsv, Mask, Delta, X_last_obsv_b, Delta_b), axis=1)

    train_index = int(np.floor(sample_size * train_propotion))
    valid_index = int(np.floor(sample_size * (train_propotion + valid_propotion)))

    if masking:
        train_data, train_label = dataset_agger[:train_index], speed_labels[:train_index]
        valid_data, valid_label = dataset_agger[train_index:valid_index], speed_labels[train_index:valid_index]
        test_data, test_label = dataset_agger[valid_index:], speed_labels[valid_index:]
    else:
        train_data, train_label = speed_sequences[:train_index], speed_labels[:train_index]
        valid_data, valid_label = speed_sequences[train_index:valid_index], speed_labels[train_index:valid_index]
        test_data, test_label = speed_sequences[valid_index:], speed_labels[valid_index:]

    train_data, train_label = torch.Tensor(train_data), torch.Tensor(train_label)
    valid_data, valid_label = torch.Tensor(valid_data), torch.Tensor(valid_label)
    test_data, test_label = torch.Tensor(test_data), torch.Tensor(test_label)

    train_dataset = utils.TensorDataset(train_data, train_label)
    valid_dataset = utils.TensorDataset(valid_data, valid_label)
    test_dataset = utils.TensorDataset(test_data, test_label)

    train_dataloader = utils.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, drop_last=True)
    valid_dataloader = utils.DataLoader(valid_dataset, batch_size=BATCH_SIZE, shuffle=True, drop_last=True)
    test_dataloader = utils.DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True, drop_last=True)

    X_mean = np.mean(speed_sequences, axis=0)

    print("Finished")

    return train_dataloader, valid_dataloader, test_dataloader, max_speed, X_mean


def Train_Model(
    model,
    discriminator,
    train_dataloader,
    valid_dataloader,
    num_epochs=300,
    patience=10,
    min_delta=0.00001,
    lambda_dis=0.1,
):
    print("Model Structure: ", model)
    print("Start Training ... ")

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    model.to(device)
    discriminator.to(device)

    if type(model) == nn.modules.container.Sequential:
        output_last = model[-1].output_last
        print("Output type dermined by the last layer")
    else:
        output_last = model.output_last
        print("Output type dermined by the model")

    loss_MSE = torch.nn.MSELoss()
    loss_L1 = torch.nn.L1Loss()

    learning_rate = 0.0005
    optimizer = torch.optim.RMSprop(model.parameters(), lr=learning_rate)
    optimizer_adv = torch.optim.RMSprop(discriminator.parameters(), lr=learning_rate)
    adversarial_loss = wasserstein_loss
    use_gpu = torch.cuda.is_available()

    interval = 100
    losses_train = []
    losses_valid = []
    losses_epochs_train = []
    losses_epochs_valid = []
    losses_epochs_d_loss_real = []
    losses_epochs_d_loss_fake = []

    cur_time = time.time()
    pre_time = time.time()

    # Variables for Early Stopping
    is_best_model = 0
    patient_epoch = 0
    for epoch in range(num_epochs):
        model.train()
        discriminator.train()
        # if use_gpu:
        #     mem_allocated = torch.cuda.memory_allocated() / (1024 * 1024)  # MB単位で取得
        #     print(f"Epoch {epoch}: GPU memory allocated at start of epoch: {mem_allocated:.2f} MB")

        trained_number = 0

        valid_dataloader_iter = iter(valid_dataloader)

        losses_epoch_train = []
        losses_epoch_valid = []

        losses_epoch_d_loss_real = []
        losses_epoch_d_loss_fake = []

        # if use_gpu:
        #     mem_allocated = torch.cuda.memory_allocated() / (1024 * 1024)  # MB単位で取得
        #     print(f"Epoch {epoch}: GPU memory allocated at before train: {mem_allocated:.2f} MB")

        for data in train_dataloader:
            model.train()
            discriminator.train()
            inputs, labels = data

            if inputs.shape[0] != batch_size:
                continue

            if use_gpu:
                inputs, labels = inputs.cuda(), labels.cuda()
            else:
                inputs, labels = inputs, labels

            # print("inputs")
            # print(inputs.shape)

            optimizer_adv.zero_grad()

            forecasts, generation = model(inputs)
            real_predictions = discriminator(labels)
            fake_predictions = discriminator(generation.detach())

            d_loss_real = adversarial_loss(real_predictions, torch.ones_like(real_predictions))
            d_loss_fake = adversarial_loss(fake_predictions, torch.ones_like(fake_predictions))

            d_loss = -d_loss_real + d_loss_fake
            # print(f"d_loss_real: {d_loss_real}")
            # print(f"d_loss_fake: {d_loss_fake}")

            losses_epoch_d_loss_real.append(d_loss_real.data)
            losses_epoch_d_loss_fake.append(d_loss_fake.data)

            d_loss.backward()

            optimizer_adv.step()

            # print("forecasts")
            # print(forecasts.shape)

            optimizer.zero_grad()

            # Forecasting
            outputs, generations = model(inputs)

            forecasts_prediction = discriminator(generations.detach())
            g_loss_forecast = adversarial_loss(forecasts_prediction, torch.ones_like(forecasts_prediction))

            # print(f"generations: {generations.shape}")
            # print(f"forecasts_prediction: {forecasts_prediction.shape}")

            if output_last:
                loss_train = loss_MSE(torch.squeeze(outputs), torch.squeeze(labels)) - lambda_dis * g_loss_forecast
            else:
                full_labels = torch.cat((inputs[:, 1:, :], labels), dim=1)
                loss_train = loss_MSE(outputs, full_labels) - lambda_dis * g_loss_forecast

            losses_train.append(loss_train.data)
            losses_epoch_train.append(loss_train.data)

            # print(f"loss_train: {loss_train}")

            loss_train.backward()

            # torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            # print(model.memory)

            # print(
            #     f"Epoch [{epoch}]  D Loss Real: {d_loss_real.item():.4f}  D Loss Fake: {d_loss_fake.item():.4f}  D Loss: {d_loss.item():.4f}"
            # )
            # print(
            #     f"Forecasting Loss: {loss.item():.4f}  G Loss Forecast: {g_loss_forecast.item():.4f}  G Loss: {g_loss.item():.4f}"
            # )

            # validation
            model.eval()
            try:
                inputs_val, labels_val = next(valid_dataloader_iter)
            except StopIteration:
                valid_dataloader_iter = iter(valid_dataloader)
                inputs_val, labels_val = next(valid_dataloader_iter)

            if use_gpu:
                inputs_val, labels_val = inputs_val.cuda(), labels_val.cuda()
            else:
                inputs_val, labels_val = inputs_val, labels_val

            with torch.no_grad():
                outputs_val, generations = model(inputs_val)

                if output_last:
                    loss_valid = loss_MSE(torch.squeeze(outputs_val), torch.squeeze(labels_val))
                else:
                    full_labels_val = torch.cat((inputs_val[:, 1:, :], labels_val), dim=1)
                    loss_valid = loss_MSE(outputs_val, full_labels_val)

            losses_valid.append(loss_valid.data)
            losses_epoch_valid.append(loss_valid.data)

            del inputs_val, labels_val, outputs_val, loss_valid, data
            torch.cuda.empty_cache()

            # if use_gpu:
            #     mem_allocated = torch.cuda.memory_allocated() / (1024 * 1024)  # MB単位で取得
            #     print(
            #         f"Epoch {epoch}, Step {trained_number}: GPU memory allocated after validation step: {mem_allocated:.2f} MB"
            #     )

            # output
            trained_number += 1

        if epoch%10==0:
            plot_heatmap(model.s_i, epoch)
            plot_memorymap(model.memory, epoch)
        avg_losses_epoch_train = sum(losses_epoch_train).cpu().numpy() / float(len(losses_epoch_train))
        avg_losses_epoch_valid = sum(losses_epoch_valid).cpu().numpy() / float(len(losses_epoch_valid))
        losses_epochs_train.append(avg_losses_epoch_train)
        losses_epochs_valid.append(avg_losses_epoch_valid)

        avg_losses_epoch_d_loss_real = sum(losses_epoch_d_loss_real).cpu().numpy() / float(
            len(losses_epoch_d_loss_real)
        )
        avg_losses_epoch_d_loss_fake = sum(losses_epoch_d_loss_fake).cpu().numpy() / float(
            len(losses_epoch_d_loss_fake)
        )
        losses_epochs_d_loss_real.append(avg_losses_epoch_d_loss_real)
        losses_epochs_d_loss_fake.append(avg_losses_epoch_d_loss_fake)

        # Early Stopping
        if epoch == 0:
            is_best_model = 1
            best_model = model
            min_loss_epoch_valid = 10000.0
            if avg_losses_epoch_valid < min_loss_epoch_valid:
                min_loss_epoch_valid = avg_losses_epoch_valid
        else:
            if min_loss_epoch_valid - avg_losses_epoch_valid > min_delta:
                is_best_model = 1
                best_model = model
                min_loss_epoch_valid = avg_losses_epoch_valid
                patient_epoch = 0
            else:
                is_best_model = 0
                patient_epoch += 1
                if patient_epoch >= patience:
                    print("Early Stopped at Epoch:", epoch)
                    plot_heatmap(model.s_i, epoch)
                    plot_memorymap(model.memory, epoch)
                    break

        # Print training parameters
        cur_time = time.time()
        print(
            "Epoch: {}, train_loss: {}, d_loss_real: {}, d_loss_fake: {}, valid_loss: {}, time: {}, best model: {}".format(
                epoch,
                np.around(avg_losses_epoch_train, decimals=8),
                np.around(avg_losses_epoch_d_loss_real, decimals=8),
                np.around(avg_losses_epoch_d_loss_fake, decimals=8),
                np.around(avg_losses_epoch_valid, decimals=8),
                np.around([cur_time - pre_time], decimals=2),
                is_best_model,
            )
        )
        pre_time = cur_time

        if use_gpu:
            mem_allocated = torch.cuda.memory_allocated() / (1024 * 1024)  # MB単位で取得
            print(f"Epoch {epoch}: GPU memory allocated at end of epoch: {mem_allocated:.2f} MB")

    plot_losses_combined(
        losses_epochs_train,
        losses_epochs_valid,
        losses_epochs_d_loss_real,
        losses_epochs_d_loss_fake,
        "combined_losses.png",
    )

    return best_model, [losses_train, losses_valid, losses_epochs_train, losses_epochs_valid]


def Test_Model(model, test_dataloader, max_speed):
    if type(model) == nn.modules.container.Sequential:
        output_last = model[-1].output_last
    else:
        output_last = model.output_last

    inputs, labels = next(iter(test_dataloader))
    [batch_size, type_size, step_size, fea_size] = inputs.size()

    cur_time = time.time()
    pre_time = time.time()

    use_gpu = torch.cuda.is_available()

    loss_MSE = torch.nn.MSELoss()
    loss_L1 = torch.nn.MSELoss()

    tested_batch = 0

    losses_mse = []
    losses_l1 = []
    MAEs = []
    MAPEs = []

    for data in test_dataloader:
        inputs, labels = data

        if inputs.shape[0] != batch_size:
            continue

        if use_gpu:
            inputs, labels = inputs.cuda(), labels.cuda()
        else:
            inputs, labels = inputs, labels

        outputs, generation = model(inputs)

        loss_MSE = torch.nn.MSELoss()
        loss_L1 = torch.nn.L1Loss()

        if output_last:
            loss_mse = loss_MSE(torch.squeeze(outputs), torch.squeeze(labels))
            loss_l1 = loss_L1(torch.squeeze(outputs), torch.squeeze(labels))
            MAE = torch.mean(torch.abs(torch.squeeze(outputs) - torch.squeeze(labels)))
            MAPE = torch.mean(torch.abs(torch.squeeze(outputs) - torch.squeeze(labels)) / torch.squeeze(labels))
        else:
            loss_mse = loss_MSE(outputs[:, -1, :], labels)
            loss_l1 = loss_L1(outputs[:, -1, :], labels)
            MAE = torch.mean(torch.abs(outputs[:, -1, :] - torch.squeeze(labels)))
            MAPE = torch.mean(torch.abs(outputs[:, -1, :] - torch.squeeze(labels)) / torch.squeeze(labels))

        losses_mse.append(loss_mse.data.cpu().numpy())  # Move to CPU and convert to NumPy array
        losses_l1.append(loss_l1.data.cpu().numpy())  # Move to CPU and convert to NumPy array
        MAEs.append(MAE.data.cpu().numpy())  # Move to CPU and convert to NumPy array
        MAPEs.append(MAPE.data.cpu().numpy())  # Move to CPU and convert to NumPy array

        tested_batch += 1

        if tested_batch % 1000 == 0:
            cur_time = time.time()
            print(
                "Tested #: {}, loss_l1: {}, loss_mse: {}, time: {}".format(
                    tested_batch * batch_size,
                    np.around([loss_l1.data[0]], decimals=8),
                    np.around([loss_mse.data[0]], decimals=8),
                    np.around([cur_time - pre_time], decimals=8),
                )
            )
            pre_time = cur_time
    losses_l1 = np.array(losses_l1)
    losses_mse = np.array(losses_mse)
    MAEs = np.array(MAEs)
    MAPEs = np.array(MAPEs)

    mean_l1 = np.mean(losses_l1) * max_speed
    std_l1 = np.std(losses_l1) * max_speed
    MAE_ = np.mean(MAEs) * max_speed
    MAPE_ = np.mean(MAPEs) * 100

    print("Tested: L1_mean: {}, L1_std: {}, MAE: {} MAPE: {}".format(mean_l1, std_l1, MAE_, MAPE_))
    return [losses_l1, losses_mse, mean_l1, std_l1]


if __name__ == "__main__":
    data = "loop"
    if data == "inrix":
        speed_matrix = pd.read_pickle("../Data_Warehouse/Data_network_traffic/inrix_seattle_speed_matrix_2012")
    elif data == "loop":
        speed_matrix = pd.read_pickle("/workspaces/STdata_prediction/src/GRU-D-zhiyongc/input/speed_matrix_2015")

    train_dataloader, valid_dataloader, test_dataloader, max_speed, X_mean = PrepareDataset(
        speed_matrix, BATCH_SIZE=32, masking=True
    )

    inputs, labels = next(iter(train_dataloader))
    [batch_size, type_size, step_size, fea_size] = inputs.size()
    input_dim = fea_size
    hidden_dim = fea_size
    output_dim = fea_size

    lgnet = LGnet(
        input_dim, hidden_dim, output_dim, X_mean, memory_size=64, memory_dim=128, num_layers=1, output_last=True
    )
    adv = Discriminator(input_dim)
    best_lgnet, losses_lgnet = Train_Model(lgnet, adv, train_dataloader, valid_dataloader, lambda_dis=10.0)
    [losses_l1, losses_mse, mean_l1, std_l1] = Test_Model(best_lgnet, test_dataloader, max_speed)
# Out:
# /workspaces/STdata_prediction/.venv/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# Time len:  6570
# Split Speed finished. Start to generate Mask, Delta, Last_observed_X ...
# Generate Mask, Delta, Last_observed_X finished. Start to shuffle and split dataset ...
# Finished
# Model Structure:  LGnet(
#   (il): Linear(in_features=451, out_features=323, bias=True)
#   (fl): Linear(in_features=451, out_features=323, bias=True)
#   (ol): Linear(in_features=451, out_features=323, bias=True)
#   (cl): Linear(in_features=451, out_features=323, bias=True)
#   (fc): Linear(in_features=323, out_features=323, bias=True)
#   (gamma_z_l): FilterLinear(in_features=323, out_features=323, bias=True)
#   (gamma_z_prime_l): FilterLinear(in_features=323, out_features=323, bias=True)
#   (q_for_memory): Linear(in_features=969, out_features=128, bias=True)
# )
# Start Training ...
# Output type dermined by the model
# Epoch: 0, train_loss: -1.28451655, d_loss_real: 0.98627243, d_loss_fake: 0.14632731, valid_loss: 0.05282046, time: [5.1], best model: 1
# Epoch 0: GPU memory allocated at end of epoch: 447.41 MB
# Epoch: 1, train_loss: -1.50450999, d_loss_real: 0.98529394, d_loss_fake: 0.1560123, valid_loss: 0.01843685, time: [4.56], best model: 1
# Epoch 1: GPU memory allocated at end of epoch: 453.14 MB
# Epoch: 2, train_loss: -1.04681919, d_loss_real: 0.97403071, d_loss_fake: 0.11715282, valid_loss: 0.01440336, time: [4.57], best model: 1
# Epoch 2: GPU memory allocated at end of epoch: 458.86 MB
# Epoch: 3, train_loss: -0.01017653, d_loss_real: 0.99579199, d_loss_fake: 0.00367826, valid_loss: 0.01043119, time: [4.56], best model: 1
# Epoch 3: GPU memory allocated at end of epoch: 464.59 MB
# Epoch: 4, train_loss: -0.30123813, d_loss_real: 0.96837483, d_loss_fake: 0.04475072, valid_loss: 0.00941815, time: [4.59], best model: 1
# Epoch 4: GPU memory allocated at end of epoch: 470.31 MB
# Epoch: 5, train_loss: -0.11614647, d_loss_real: 0.9630383, d_loss_fake: 0.02696272, valid_loss: 0.00756775, time: [4.59], best model: 1
# Epoch 5: GPU memory allocated at end of epoch: 476.04 MB
# Epoch: 6, train_loss: -0.13688965, d_loss_real: 0.97488051, d_loss_fake: 0.02847844, valid_loss: 0.00701876, time: [4.63], best model: 1
# Epoch 6: GPU memory allocated at end of epoch: 481.77 MB
# Epoch: 7, train_loss: -0.100668, d_loss_real: 0.98188003, d_loss_fake: 0.01333664, valid_loss: 0.00649486, time: [4.96], best model: 1
# Epoch 7: GPU memory allocated at end of epoch: 487.49 MB
# Epoch: 8, train_loss: -0.01285754, d_loss_real: 0.99600305, d_loss_fake: 0.00276846, valid_loss: 0.00631172, time: [4.96], best model: 1
# Epoch 8: GPU memory allocated at end of epoch: 493.22 MB
# Epoch: 9, train_loss: -0.09061709, d_loss_real: 0.99111085, d_loss_fake: 0.01203334, valid_loss: 0.00585731, time: [5.], best model: 1
# Epoch 9: GPU memory allocated at end of epoch: 498.94 MB
# Epoch: 10, train_loss: -0.00974451, d_loss_real: 0.99426387, d_loss_fake: 0.00445758, valid_loss: 0.00557521, time: [5.17], best model: 1
# Epoch 10: GPU memory allocated at end of epoch: 504.67 MB
# Epoch: 11, train_loss: -0.03698515, d_loss_real: 0.99566181, d_loss_fake: 0.00445485, valid_loss: 0.00543106, time: [4.96], best model: 1
# Epoch 11: GPU memory allocated at end of epoch: 510.39 MB
# Epoch: 12, train_loss: -0.02628128, d_loss_real: 0.99071647, d_loss_fake: 0.0059427, valid_loss: 0.00522986, time: [4.99], best model: 1
# Epoch 12: GPU memory allocated at end of epoch: 516.12 MB
# Epoch: 13, train_loss: -0.05015804, d_loss_real: 0.99637855, d_loss_fake: 0.00513838, valid_loss: 0.00518017, time: [4.98], best model: 1
# Epoch 13: GPU memory allocated at end of epoch: 521.84 MB
# Epoch: 14, train_loss: -0.06533673, d_loss_real: 0.99619042, d_loss_fake: 0.00764087, valid_loss: 0.0050824, time: [4.84], best model: 1
# Epoch 14: GPU memory allocated at end of epoch: 527.57 MB
# Epoch: 15, train_loss: -0.16859256, d_loss_real: 0.99149723, d_loss_fake: 0.02152009, valid_loss: 0.0049353, time: [4.85], best model: 1
# Epoch 15: GPU memory allocated at end of epoch: 533.30 MB
# Epoch: 16, train_loss: -0.1390663, d_loss_real: 0.99423901, d_loss_fake: 0.01568565, valid_loss: 0.00481804, time: [4.94], best model: 1
# Epoch 16: GPU memory allocated at end of epoch: 539.02 MB
# Epoch: 17, train_loss: -0.11158429, d_loss_real: 0.98496625, d_loss_fake: 0.01703577, valid_loss: 0.0048007, time: [4.93], best model: 1
# Epoch 17: GPU memory allocated at end of epoch: 544.75 MB
# Epoch: 18, train_loss: -0.12839793, d_loss_real: 0.99030896, d_loss_fake: 0.01570082, valid_loss: 0.00470367, time: [4.96], best model: 1
# Epoch 18: GPU memory allocated at end of epoch: 550.47 MB
# Epoch: 19, train_loss: -0.09879154, d_loss_real: 0.98987147, d_loss_fake: 0.01487713, valid_loss: 0.00459451, time: [4.9], best model: 1
# Epoch 19: GPU memory allocated at end of epoch: 556.20 MB
# Epoch: 20, train_loss: -0.01118419, d_loss_real: 0.99092081, d_loss_fake: 0.00542027, valid_loss: 0.00454833, time: [5.09], best model: 1
# Epoch 20: GPU memory allocated at end of epoch: 561.92 MB
# Epoch: 21, train_loss: -0.13248244, d_loss_real: 0.9813847, d_loss_fake: 0.01195451, valid_loss: 0.00453076, time: [4.97], best model: 1
# Epoch 21: GPU memory allocated at end of epoch: 567.65 MB
# Epoch: 22, train_loss: -0.10719147, d_loss_real: 0.98918269, d_loss_fake: 0.01146966, valid_loss: 0.0043857, time: [5.08], best model: 1
# Epoch 22: GPU memory allocated at end of epoch: 573.38 MB
# Epoch: 23, train_loss: -0.28670582, d_loss_real: 0.98873016, d_loss_fake: 0.03699618, valid_loss: 0.00441285, time: [4.96], best model: 0
# Epoch 23: GPU memory allocated at end of epoch: 579.10 MB
# Epoch: 24, train_loss: -0.01489085, d_loss_real: 0.99073013, d_loss_fake: 0.00559362, valid_loss: 0.0043569, time: [4.95], best model: 1
# Epoch 24: GPU memory allocated at end of epoch: 584.83 MB
# Epoch: 25, train_loss: -0.10501029, d_loss_real: 0.97620483, d_loss_fake: 0.01427941, valid_loss: 0.00427776, time: [5.06], best model: 1
# Epoch 25: GPU memory allocated at end of epoch: 590.55 MB
# Epoch: 26, train_loss: -0.08643571, d_loss_real: 0.98796284, d_loss_fake: 0.01138589, valid_loss: 0.0042237, time: [5.18], best model: 1
# Epoch 26: GPU memory allocated at end of epoch: 596.28 MB
# Epoch: 27, train_loss: -0.35880365, d_loss_real: 0.99570342, d_loss_fake: 0.02940134, valid_loss: 0.00414968, time: [5.04], best model: 1
# Epoch 27: GPU memory allocated at end of epoch: 602.00 MB
# Epoch: 28, train_loss: -0.60484463, d_loss_real: 0.98743615, d_loss_fake: 0.07230345, valid_loss: 0.00414185, time: [4.96], best model: 0
# Epoch 28: GPU memory allocated at end of epoch: 607.73 MB
# Epoch: 29, train_loss: -0.11269923, d_loss_real: 0.98386548, d_loss_fake: 0.01385594, valid_loss: 0.00402603, time: [4.91], best model: 1
# Epoch 29: GPU memory allocated at end of epoch: 613.45 MB
# Epoch: 30, train_loss: -0.00652907, d_loss_real: 0.99791211, d_loss_fake: 0.00206639, valid_loss: 0.00395822, time: [5.19], best model: 1
# Epoch 30: GPU memory allocated at end of epoch: 619.18 MB
# Epoch: 31, train_loss: -0.11984602, d_loss_real: 0.992404, d_loss_fake: 0.01659763, valid_loss: 0.00393786, time: [5.08], best model: 1
# Epoch 31: GPU memory allocated at end of epoch: 624.91 MB
# Epoch: 32, train_loss: -0.00501514, d_loss_real: 0.99672875, d_loss_fake: 0.00142978, valid_loss: 0.00395802, time: [5.02], best model: 0
# Epoch 32: GPU memory allocated at end of epoch: 630.63 MB
# Epoch: 33, train_loss: -0.11174651, d_loss_real: 0.98214017, d_loss_fake: 0.01704971, valid_loss: 0.00387099, time: [5.1], best model: 1
# Epoch 33: GPU memory allocated at end of epoch: 636.36 MB
# Epoch: 34, train_loss: 0.00274488, d_loss_real: 0.99876105, d_loss_fake: 0.00089342, valid_loss: 0.00382647, time: [5.07], best model: 1
# Epoch 34: GPU memory allocated at end of epoch: 642.08 MB
# Epoch: 35, train_loss: -0.21263459, d_loss_real: 0.98607417, d_loss_fake: 0.02569284, valid_loss: 0.00379503, time: [5.], best model: 1
# Epoch 35: GPU memory allocated at end of epoch: 647.81 MB
# Epoch: 36, train_loss: -0.08231526, d_loss_real: 0.99161972, d_loss_fake: 0.00647994, valid_loss: 0.00378389, time: [5.07], best model: 1
# Epoch 36: GPU memory allocated at end of epoch: 653.53 MB
# Epoch: 37, train_loss: -0.13374649, d_loss_real: 0.99420849, d_loss_fake: 0.01394023, valid_loss: 0.00373471, time: [5.05], best model: 1
# Epoch 37: GPU memory allocated at end of epoch: 659.26 MB
# Epoch: 38, train_loss: -0.03384921, d_loss_real: 0.99175705, d_loss_fake: 0.00475127, valid_loss: 0.00368386, time: [5.15], best model: 1
# Epoch 38: GPU memory allocated at end of epoch: 664.98 MB
# Epoch: 39, train_loss: -0.03754576, d_loss_real: 0.99735489, d_loss_fake: 0.00447707, valid_loss: 0.00366761, time: [5.09], best model: 1
# Epoch 39: GPU memory allocated at end of epoch: 670.71 MB
# Epoch: 40, train_loss: -0.06446113, d_loss_real: 0.99448048, d_loss_fake: 0.00719215, valid_loss: 0.00364381, time: [5.36], best model: 1
# Epoch 40: GPU memory allocated at end of epoch: 676.44 MB
# Epoch: 41, train_loss: -0.00208927, d_loss_real: 0.99474884, d_loss_fake: 0.0038704, valid_loss: 0.00358692, time: [5.16], best model: 1
# Epoch 41: GPU memory allocated at end of epoch: 682.16 MB
# Epoch: 42, train_loss: -0.15913831, d_loss_real: 0.99222698, d_loss_fake: 0.01589382, valid_loss: 0.00354757, time: [5.08], best model: 1
# Epoch 42: GPU memory allocated at end of epoch: 687.89 MB
# Epoch: 43, train_loss: -0.00034071, d_loss_real: 0.99953615, d_loss_fake: 0.00090263, valid_loss: 0.00356481, time: [5.07], best model: 0
# Epoch 43: GPU memory allocated at end of epoch: 693.61 MB
# Epoch: 44, train_loss: -0.19429534, d_loss_real: 0.99199874, d_loss_fake: 0.02356824, valid_loss: 0.00354367, time: [5.18], best model: 0
# Epoch 44: GPU memory allocated at end of epoch: 699.34 MB
# Epoch: 45, train_loss: -0.0534117, d_loss_real: 0.99306195, d_loss_fake: 0.00724764, valid_loss: 0.00347941, time: [5.17], best model: 1
# Epoch 45: GPU memory allocated at end of epoch: 705.06 MB
# Epoch: 46, train_loss: -0.0845527, d_loss_real: 0.99410637, d_loss_fake: 0.01442084, valid_loss: 0.00346179, time: [5.16], best model: 1
# Epoch 46: GPU memory allocated at end of epoch: 710.79 MB
# Epoch: 47, train_loss: -0.01120577, d_loss_real: 0.99912427, d_loss_fake: 0.00218895, valid_loss: 0.0034849, time: [5.11], best model: 0
# Epoch 47: GPU memory allocated at end of epoch: 716.51 MB
# Epoch: 48, train_loss: -0.1193814, d_loss_real: 0.99427273, d_loss_fake: 0.01420026, valid_loss: 0.00339558, time: [5.14], best model: 1
# Epoch 48: GPU memory allocated at end of epoch: 722.24 MB
# Epoch: 49, train_loss: -0.02447762, d_loss_real: 0.99217715, d_loss_fake: 0.00448145, valid_loss: 0.00343125, time: [5.1], best model: 0
# Epoch 49: GPU memory allocated at end of epoch: 727.97 MB
# Epoch: 50, train_loss: -0.04278267, d_loss_real: 0.99028506, d_loss_fake: 0.01070554, valid_loss: 0.00334471, time: [5.41], best model: 1
# Epoch 50: GPU memory allocated at end of epoch: 733.69 MB
# Epoch: 51, train_loss: -0.01084104, d_loss_real: 0.99888739, d_loss_fake: 0.00269201, valid_loss: 0.00334809, time: [5.29], best model: 0
# Epoch 51: GPU memory allocated at end of epoch: 739.42 MB
# Epoch: 52, train_loss: -0.00144968, d_loss_real: 0.99012543, d_loss_fake: 0.006523, valid_loss: 0.00332455, time: [5.3], best model: 1
# Epoch 52: GPU memory allocated at end of epoch: 745.14 MB
# Epoch: 53, train_loss: 0.0029847, d_loss_real: 0.99969098, d_loss_fake: 0.00068253, valid_loss: 0.00330603, time: [5.3], best model: 1
# Epoch 53: GPU memory allocated at end of epoch: 750.87 MB
# Epoch: 54, train_loss: -0.08055056, d_loss_real: 0.98877625, d_loss_fake: 0.01225081, valid_loss: 0.00329685, time: [5.14], best model: 0
# Epoch 54: GPU memory allocated at end of epoch: 756.59 MB
# Epoch: 55, train_loss: -0.07008433, d_loss_real: 0.99717318, d_loss_fake: 0.00681129, valid_loss: 0.00328028, time: [5.16], best model: 1
# Epoch 55: GPU memory allocated at end of epoch: 762.32 MB
# Epoch: 56, train_loss: -0.06747769, d_loss_real: 0.99880213, d_loss_fake: 0.00338135, valid_loss: 0.00324728, time: [5.23], best model: 1
# Epoch 56: GPU memory allocated at end of epoch: 768.04 MB
# Epoch: 57, train_loss: -0.10882492, d_loss_real: 0.99271409, d_loss_fake: 0.01506927, valid_loss: 0.00323848, time: [5.34], best model: 0
# Epoch 57: GPU memory allocated at end of epoch: 773.77 MB
# Epoch: 58, train_loss: 0.00248795, d_loss_real: 0.99889304, d_loss_fake: 0.0005788, valid_loss: 0.00323109, time: [5.33], best model: 1
# Epoch 58: GPU memory allocated at end of epoch: 779.50 MB
# Epoch: 59, train_loss: -0.14439591, d_loss_real: 0.99526519, d_loss_fake: 0.01904457, valid_loss: 0.00319095, time: [5.27], best model: 1
# Epoch 59: GPU memory allocated at end of epoch: 785.22 MB
# Epoch: 60, train_loss: -0.09012694, d_loss_real: 0.99747686, d_loss_fake: 0.0076736, valid_loss: 0.00316541, time: [5.48], best model: 1
# Epoch 60: GPU memory allocated at end of epoch: 790.95 MB
# Epoch: 61, train_loss: -0.08992176, d_loss_real: 0.99717787, d_loss_fake: 0.01109166, valid_loss: 0.00315975, time: [5.51], best model: 0
# Epoch 61: GPU memory allocated at end of epoch: 796.67 MB
# Epoch: 62, train_loss: -0.05069164, d_loss_real: 0.99766519, d_loss_fake: 0.002947, valid_loss: 0.003134, time: [5.62], best model: 1
# Epoch 62: GPU memory allocated at end of epoch: 802.40 MB
# Epoch: 63, train_loss: -0.01525262, d_loss_real: 0.99933064, d_loss_fake: 0.00210661, valid_loss: 0.00312459, time: [5.27], best model: 0
# Epoch 63: GPU memory allocated at end of epoch: 808.12 MB
# Epoch: 64, train_loss: -0.07002367, d_loss_real: 0.99217534, d_loss_fake: 0.00430576, valid_loss: 0.00308025, time: [5.4], best model: 1
# Epoch 64: GPU memory allocated at end of epoch: 813.85 MB
# Epoch: 65, train_loss: -0.00832304, d_loss_real: 0.99459572, d_loss_fake: 0.00366749, valid_loss: 0.00306646, time: [5.54], best model: 1
# Epoch 65: GPU memory allocated at end of epoch: 819.58 MB
# Epoch: 66, train_loss: -0.11666291, d_loss_real: 0.99667028, d_loss_fake: 0.01066914, valid_loss: 0.00308755, time: [5.44], best model: 0
# Epoch 66: GPU memory allocated at end of epoch: 825.30 MB
# Epoch: 67, train_loss: -0.06899342, d_loss_real: 0.98890494, d_loss_fake: 0.0095645, valid_loss: 0.00311664, time: [5.46], best model: 0
# Epoch 67: GPU memory allocated at end of epoch: 831.03 MB
# Epoch: 68, train_loss: -0.19105188, d_loss_real: 0.98936505, d_loss_fake: 0.01802519, valid_loss: 0.00302132, time: [5.33], best model: 1
# Epoch 68: GPU memory allocated at end of epoch: 836.75 MB
# Epoch: 69, train_loss: -0.05870555, d_loss_real: 0.99019223, d_loss_fake: 0.00757271, valid_loss: 0.00301877, time: [5.4], best model: 0
# Epoch 69: GPU memory allocated at end of epoch: 842.48 MB
# Epoch: 70, train_loss: -0.33694634, d_loss_real: 0.99043519, d_loss_fake: 0.04165421, valid_loss: 0.00303914, time: [5.65], best model: 0
# Epoch 70: GPU memory allocated at end of epoch: 848.20 MB
# Epoch: 71, train_loss: 0.00138992, d_loss_real: 0.99723827, d_loss_fake: 0.00399254, valid_loss: 0.0029874, time: [5.42], best model: 1
# Epoch 71: GPU memory allocated at end of epoch: 853.93 MB
# Epoch: 72, train_loss: -0.02250794, d_loss_real: 0.9972818, d_loss_fake: 0.00288657, valid_loss: 0.00298753, time: [5.44], best model: 0
# Epoch 72: GPU memory allocated at end of epoch: 859.65 MB
# Epoch: 73, train_loss: -0.0020399, d_loss_real: 0.99899548, d_loss_fake: 0.00123953, valid_loss: 0.00295099, time: [5.46], best model: 1
# Epoch 73: GPU memory allocated at end of epoch: 865.38 MB
# Epoch: 74, train_loss: -0.26805232, d_loss_real: 0.99301926, d_loss_fake: 0.0300695, valid_loss: 0.00297837, time: [5.45], best model: 0
# Epoch 74: GPU memory allocated at end of epoch: 871.11 MB
# Epoch: 75, train_loss: -0.10391361, d_loss_real: 0.99670485, d_loss_fake: 0.00805135, valid_loss: 0.00294166, time: [5.48], best model: 0
# Epoch 75: GPU memory allocated at end of epoch: 876.83 MB
# Epoch: 76, train_loss: -0.03536444, d_loss_real: 0.98882, d_loss_fake: 0.00902606, valid_loss: 0.00292641, time: [5.47], best model: 1
# Epoch 76: GPU memory allocated at end of epoch: 882.56 MB
# Epoch: 77, train_loss: -0.21441918, d_loss_real: 0.99564506, d_loss_fake: 0.02465765, valid_loss: 0.00287741, time: [5.44], best model: 1
# Epoch 77: GPU memory allocated at end of epoch: 888.28 MB
# Epoch: 78, train_loss: -0.02342569, d_loss_real: 0.99181948, d_loss_fake: 0.01009904, valid_loss: 0.00293118, time: [5.52], best model: 0
# Epoch 78: GPU memory allocated at end of epoch: 894.01 MB
# Epoch: 79, train_loss: -0.14419437, d_loss_real: 0.99295503, d_loss_fake: 0.01539739, valid_loss: 0.00288139, time: [5.65], best model: 0
# Epoch 79: GPU memory allocated at end of epoch: 899.73 MB
# Epoch: 80, train_loss: -0.3373404, d_loss_real: 0.98962989, d_loss_fake: 0.04646825, valid_loss: 0.00287517, time: [5.73], best model: 0
# Epoch 80: GPU memory allocated at end of epoch: 905.46 MB
# Epoch: 81, train_loss: -0.02418285, d_loss_real: 0.99422471, d_loss_fake: 0.01156691, valid_loss: 0.00290115, time: [5.66], best model: 0
# Epoch 81: GPU memory allocated at end of epoch: 911.18 MB
# Epoch: 82, train_loss: -0.0107538, d_loss_real: 0.98997135, d_loss_fake: 0.00472833, valid_loss: 0.00287465, time: [5.52], best model: 0
# Epoch 82: GPU memory allocated at end of epoch: 916.91 MB
# Epoch: 83, train_loss: -0.05635668, d_loss_real: 0.9918995, d_loss_fake: 0.01408844, valid_loss: 0.00282326, time: [5.55], best model: 1
# Epoch 83: GPU memory allocated at end of epoch: 922.64 MB
# Epoch: 84, train_loss: -0.00187256, d_loss_real: 0.99891332, d_loss_fake: 0.00128042, valid_loss: 0.00286292, time: [5.47], best model: 0
# Epoch 84: GPU memory allocated at end of epoch: 928.36 MB
# Epoch: 85, train_loss: -0.05826681, d_loss_real: 0.99744303, d_loss_fake: 0.00288021, valid_loss: 0.00284901, time: [5.46], best model: 0
# Epoch 85: GPU memory allocated at end of epoch: 934.09 MB
# Epoch: 86, train_loss: -0.26421188, d_loss_real: 0.99200066, d_loss_fake: 0.0236743, valid_loss: 0.0027995, time: [5.49], best model: 1
# Epoch 86: GPU memory allocated at end of epoch: 939.81 MB
# Epoch: 87, train_loss: -0.00474161, d_loss_real: 0.99336307, d_loss_fake: 0.00603776, valid_loss: 0.00280521, time: [5.59], best model: 0
# Epoch 87: GPU memory allocated at end of epoch: 945.54 MB
# Epoch: 88, train_loss: -0.02555496, d_loss_real: 0.99129481, d_loss_fake: 0.00803454, valid_loss: 0.00282637, time: [5.57], best model: 0
# Epoch 88: GPU memory allocated at end of epoch: 951.26 MB
# Epoch: 89, train_loss: 0.00190028, d_loss_real: 0.99125063, d_loss_fake: 0.00712691, valid_loss: 0.00281842, time: [5.59], best model: 0
# Epoch 89: GPU memory allocated at end of epoch: 956.99 MB
# Epoch: 90, train_loss: 0.00219168, d_loss_real: 0.99969888, d_loss_fake: 0.00012642, valid_loss: 0.00275989, time: [5.77], best model: 1
# Epoch 90: GPU memory allocated at end of epoch: 962.71 MB
# Epoch: 91, train_loss: -0.04144068, d_loss_real: 0.98482711, d_loss_fake: 0.02391567, valid_loss: 0.00276385, time: [5.6], best model: 0
# Epoch 91: GPU memory allocated at end of epoch: 968.44 MB
# Epoch: 92, train_loss: -0.00310782, d_loss_real: 0.99720775, d_loss_fake: 0.00201038, valid_loss: 0.00281439, time: [5.57], best model: 0
# Epoch 92: GPU memory allocated at end of epoch: 974.17 MB
# Epoch: 93, train_loss: -0.05616055, d_loss_real: 0.99261336, d_loss_fake: 0.00907252, valid_loss: 0.00279194, time: [5.59], best model: 0
# Epoch 93: GPU memory allocated at end of epoch: 979.89 MB
# Epoch: 94, train_loss: -0.36082669, d_loss_real: 0.99642432, d_loss_fake: 0.03568933, valid_loss: 0.00275918, time: [5.57], best model: 0
# Epoch 94: GPU memory allocated at end of epoch: 985.62 MB
# Epoch: 95, train_loss: -0.02971094, d_loss_real: 0.99852353, d_loss_fake: 0.00049646, valid_loss: 0.00271332, time: [5.56], best model: 1
# Epoch 95: GPU memory allocated at end of epoch: 991.34 MB
# Epoch: 96, train_loss: -0.17089486, d_loss_real: 0.99068424, d_loss_fake: 0.02189336, valid_loss: 0.00277252, time: [5.63], best model: 0
# Epoch 96: GPU memory allocated at end of epoch: 997.07 MB
# Epoch: 97, train_loss: 0.00157362, d_loss_real: 0.99733921, d_loss_fake: 0.0097816, valid_loss: 0.00274369, time: [5.65], best model: 0
# Epoch 97: GPU memory allocated at end of epoch: 1002.79 MB
# Epoch: 98, train_loss: -0.01680037, d_loss_real: 0.99266266, d_loss_fake: 0.00360281, valid_loss: 0.00273483, time: [5.54], best model: 0
# Epoch 98: GPU memory allocated at end of epoch: 1008.52 MB
# Epoch: 99, train_loss: -0.08889839, d_loss_real: 0.99375627, d_loss_fake: 0.01384548, valid_loss: 0.00270964, time: [5.58], best model: 0
# Epoch 99: GPU memory allocated at end of epoch: 1014.25 MB
# Epoch: 100, train_loss: -0.18574218, d_loss_real: 0.99420038, d_loss_fake: 0.02347746, valid_loss: 0.00270279, time: [5.77], best model: 1
# Epoch 100: GPU memory allocated at end of epoch: 1019.97 MB
# Epoch: 101, train_loss: 0.00201283, d_loss_real: 0.99984816, d_loss_fake: 0.00025941, valid_loss: 0.00270966, time: [5.69], best model: 0
# Epoch 101: GPU memory allocated at end of epoch: 1025.70 MB
# Epoch: 102, train_loss: -0.14680833, d_loss_real: 0.99691815, d_loss_fake: 0.01615114, valid_loss: 0.00269913, time: [5.64], best model: 0
# Epoch 102: GPU memory allocated at end of epoch: 1031.42 MB
# Epoch: 103, train_loss: -0.08993598, d_loss_real: 0.99504175, d_loss_fake: 0.00718552, valid_loss: 0.00271334, time: [5.6], best model: 0
# Epoch 103: GPU memory allocated at end of epoch: 1037.15 MB
# Epoch: 104, train_loss: -0.00296492, d_loss_real: 0.99849077, d_loss_fake: 0.00095825, valid_loss: 0.00267584, time: [5.58], best model: 1
# Epoch 104: GPU memory allocated at end of epoch: 1042.87 MB
# Epoch: 105, train_loss: -0.00368638, d_loss_real: 0.99839142, d_loss_fake: 0.00162909, valid_loss: 0.0026643, time: [5.56], best model: 1
# Epoch 105: GPU memory allocated at end of epoch: 1048.60 MB
# Epoch: 106, train_loss: -0.11091363, d_loss_real: 0.99480486, d_loss_fake: 0.01501139, valid_loss: 0.00267492, time: [5.72], best model: 0
# Epoch 106: GPU memory allocated at end of epoch: 1054.32 MB
# Epoch: 107, train_loss: -0.03064147, d_loss_real: 0.99127251, d_loss_fake: 0.00649312, valid_loss: 0.00269344, time: [5.66], best model: 0
# Epoch 107: GPU memory allocated at end of epoch: 1060.05 MB
# Epoch: 108, train_loss: -0.00677976, d_loss_real: 0.99628987, d_loss_fake: 0.00406766, valid_loss: 0.00264692, time: [5.62], best model: 1
# Epoch 108: GPU memory allocated at end of epoch: 1065.78 MB
# Epoch: 109, train_loss: -0.039279, d_loss_real: 0.99648578, d_loss_fake: 0.00567274, valid_loss: 0.00264243, time: [5.72], best model: 0
# Epoch 109: GPU memory allocated at end of epoch: 1071.50 MB
# Epoch: 110, train_loss: 0.00176266, d_loss_real: 0.99995807, d_loss_fake: 0.00015671, valid_loss: 0.00265566, time: [5.91], best model: 0
# Epoch 110: GPU memory allocated at end of epoch: 1077.23 MB
# Epoch: 111, train_loss: -0.00206307, d_loss_real: 0.99572028, d_loss_fake: 0.0043895, valid_loss: 0.00264165, time: [5.68], best model: 0
# Epoch 111: GPU memory allocated at end of epoch: 1082.95 MB
# Epoch: 112, train_loss: -0.00418959, d_loss_real: 0.99782055, d_loss_fake: 0.00091103, valid_loss: 0.00266338, time: [5.75], best model: 0
# Epoch 112: GPU memory allocated at end of epoch: 1088.68 MB
# Epoch: 113, train_loss: -0.03573036, d_loss_real: 0.99486408, d_loss_fake: 0.01015519, valid_loss: 0.00263367, time: [5.65], best model: 1
# Epoch 113: GPU memory allocated at end of epoch: 1094.40 MB
# Epoch: 114, train_loss: -0.01439033, d_loss_real: 0.99837339, d_loss_fake: 0.00209409, valid_loss: 0.00263406, time: [5.71], best model: 0
# Epoch 114: GPU memory allocated at end of epoch: 1100.13 MB
# Epoch: 115, train_loss: -0.17854597, d_loss_real: 0.99337, d_loss_fake: 0.01878957, valid_loss: 0.00258466, time: [5.75], best model: 1
# Epoch 115: GPU memory allocated at end of epoch: 1105.85 MB
# Epoch: 116, train_loss: -0.03740551, d_loss_real: 0.99654703, d_loss_fake: 0.00965192, valid_loss: 0.00263047, time: [5.66], best model: 0
# Epoch 116: GPU memory allocated at end of epoch: 1111.58 MB
# Epoch: 117, train_loss: -0.03299688, d_loss_real: 0.99707981, d_loss_fake: 0.00545435, valid_loss: 0.0026249, time: [5.74], best model: 0
# Epoch 117: GPU memory allocated at end of epoch: 1117.31 MB
# Epoch: 118, train_loss: -0.06212496, d_loss_real: 0.99731104, d_loss_fake: 0.00820334, valid_loss: 0.00259154, time: [5.77], best model: 0
# Epoch 118: GPU memory allocated at end of epoch: 1123.03 MB
# Epoch: 119, train_loss: -0.00518013, d_loss_real: 0.99728137, d_loss_fake: 0.00592714, valid_loss: 0.00263432, time: [5.79], best model: 0
# Epoch 119: GPU memory allocated at end of epoch: 1128.76 MB
# Epoch: 120, train_loss: 0.00197449, d_loss_real: 0.99997588, d_loss_fake: 4.539e-05, valid_loss: 0.00257663, time: [5.95], best model: 0
# Epoch 120: GPU memory allocated at end of epoch: 1134.48 MB
# Epoch: 121, train_loss: -0.01134346, d_loss_real: 0.99984997, d_loss_fake: 0.00016897, valid_loss: 0.00257315, time: [5.78], best model: 1
# Epoch 121: GPU memory allocated at end of epoch: 1140.21 MB
# Epoch: 122, train_loss: -0.10649772, d_loss_real: 0.99613803, d_loss_fake: 0.01191341, valid_loss: 0.00260566, time: [5.85], best model: 0
# Epoch 122: GPU memory allocated at end of epoch: 1145.93 MB
# Epoch: 123, train_loss: -0.06921776, d_loss_real: 0.99782834, d_loss_fake: 0.00438059, valid_loss: 0.00259049, time: [5.62], best model: 0
# Epoch 123: GPU memory allocated at end of epoch: 1151.66 MB
# Epoch: 124, train_loss: -0.22666576, d_loss_real: 0.9931264, d_loss_fake: 0.02743886, valid_loss: 0.00254846, time: [5.76], best model: 1
# Epoch 124: GPU memory allocated at end of epoch: 1157.38 MB
# Epoch: 125, train_loss: 0.00199654, d_loss_real: 0.99651961, d_loss_fake: 0.00331553, valid_loss: 0.0026168, time: [5.82], best model: 0
# Epoch 125: GPU memory allocated at end of epoch: 1163.11 MB
# Epoch: 126, train_loss: 0.00166475, d_loss_real: 0.99966175, d_loss_fake: 7.245e-05, valid_loss: 0.00256016, time: [5.86], best model: 0
# Epoch 126: GPU memory allocated at end of epoch: 1168.84 MB
# Epoch: 127, train_loss: -0.03190777, d_loss_real: 0.99346454, d_loss_fake: 0.00638242, valid_loss: 0.00259999, time: [5.93], best model: 0
# Epoch 127: GPU memory allocated at end of epoch: 1174.56 MB
# Epoch: 128, train_loss: 0.00205692, d_loss_real: 0.99988262, d_loss_fake: 0.00011413, valid_loss: 0.00261892, time: [5.88], best model: 0
# Epoch 128: GPU memory allocated at end of epoch: 1180.29 MB
# Epoch: 129, train_loss: 0.0014573, d_loss_real: 0.99917688, d_loss_fake: 0.00126315, valid_loss: 0.00252164, time: [5.78], best model: 1
# Epoch 129: GPU memory allocated at end of epoch: 1186.01 MB
# Epoch: 130, train_loss: 0.00123944, d_loss_real: 0.99989671, d_loss_fake: 0.00066934, valid_loss: 0.00257628, time: [6.01], best model: 0
# Epoch 130: GPU memory allocated at end of epoch: 1191.74 MB
# Epoch: 131, train_loss: -0.2334695, d_loss_real: 0.99501571, d_loss_fake: 0.03079601, valid_loss: 0.0025892, time: [5.87], best model: 0
# Epoch 131: GPU memory allocated at end of epoch: 1197.46 MB
# Epoch: 132, train_loss: -0.25049748, d_loss_real: 0.99860313, d_loss_fake: 0.02580243, valid_loss: 0.00254042, time: [5.86], best model: 0
# Epoch 132: GPU memory allocated at end of epoch: 1203.19 MB
# Epoch: 133, train_loss: 0.00156239, d_loss_real: 0.99998965, d_loss_fake: 0.00023708, valid_loss: 0.00255253, time: [5.85], best model: 0
# Epoch 133: GPU memory allocated at end of epoch: 1208.92 MB
# Epoch: 134, train_loss: -0.1825863, d_loss_real: 0.99723122, d_loss_fake: 0.02070132, valid_loss: 0.00253363, time: [5.84], best model: 0
# Epoch 134: GPU memory allocated at end of epoch: 1214.64 MB
# Epoch: 135, train_loss: 0.00193653, d_loss_real: 0.99973761, d_loss_fake: 5.107e-05, valid_loss: 0.00254351, time: [5.96], best model: 0
# Epoch 135: GPU memory allocated at end of epoch: 1220.37 MB
# Epoch: 136, train_loss: 0.00196938, d_loss_real: 0.999992, d_loss_fake: 1.512e-05, valid_loss: 0.00257749, time: [5.92], best model: 0
# Epoch 136: GPU memory allocated at end of epoch: 1226.09 MB
# Epoch: 137, train_loss: -0.03035902, d_loss_real: 0.99968554, d_loss_fake: 0.00034662, valid_loss: 0.00253266, time: [5.95], best model: 0
# Epoch 137: GPU memory allocated at end of epoch: 1231.82 MB
# Epoch: 138, train_loss: -0.09088142, d_loss_real: 0.99100884, d_loss_fake: 0.00667496, valid_loss: 0.00254712, time: [5.96], best model: 0
# Epoch 138: GPU memory allocated at end of epoch: 1237.54 MB
# Early Stopped at Epoch: 139
# Tested: L1_mean: 2.764746613281614, L1_std: 0.15989461677315417, MAE: 2.764746613281614 MAPE: 6.667827069759369

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import time

def Test_Model(model, test_dataloader, max_speed):
    if type(model) == nn.modules.container.Sequential:
        output_last = model[-1].output_last
    else:
        output_last = model.output_last

    inputs, labels = next(iter(test_dataloader))
    [batch_size, type_size, step_size, fea_size] = inputs.size()

    cur_time = time.time()
    pre_time = time.time()

    use_gpu = torch.cuda.is_available()

    loss_MSE = torch.nn.MSELoss()
    loss_L1 = torch.nn.MSELoss()

    tested_batch = 0

    losses_mse = []
    losses_l1 = []
    MAEs = []
    MAPEs = []

    all_labels = []
    all_outputs = []
    all_inputs = []

    for data in test_dataloader:
        inputs, labels = data

        if inputs.shape[0] != batch_size:
            continue

        if use_gpu:
            inputs, labels = inputs.cuda(), labels.cuda()
        else:
            inputs, labels = inputs, labels

        outputs, generation = model(inputs)

        loss_MSE = torch.nn.MSELoss()
        loss_L1 = torch.nn.L1Loss()

        if output_last:
            loss_mse = loss_MSE(torch.squeeze(outputs), torch.squeeze(labels))
            loss_l1 = loss_L1(torch.squeeze(outputs), torch.squeeze(labels))
            MAE = torch.mean(torch.abs(torch.squeeze(outputs) - torch.squeeze(labels)))
            MAPE = torch.mean(torch.abs(torch.squeeze(outputs) - torch.squeeze(labels)) / torch.squeeze(labels))

            all_labels.append(labels.cpu().detach().numpy())
            all_outputs.append(outputs.cpu().detach().numpy())
            all_inputs.append(inputs.cpu().detach().numpy())

        else:
            loss_mse = loss_MSE(outputs[:, -1, :], labels)
            loss_l1 = loss_L1(outputs[:, -1, :], labels)
            MAE = torch.mean(torch.abs(outputs[:, -1, :] - torch.squeeze(labels)))
            MAPE = torch.mean(torch.abs(outputs[:, -1, :] - torch.squeeze(labels)) / torch.squeeze(labels))

            all_labels.append(labels.cpu().detach().numpy())
            all_outputs.append(outputs[:, -1, :].cpu().detach().numpy())
            all_inputs.append(inputs.cpu().detach().numpy())

        losses_mse.append(loss_mse.data.cpu().numpy())
        losses_l1.append(loss_l1.data.cpu().numpy())
        MAEs.append(MAE.data.cpu().numpy())
        MAPEs.append(MAPE.data.cpu().numpy())

        tested_batch += 1

        if tested_batch % 1000 == 0:
            cur_time = time.time()
            print(
                "Tested #: {}, loss_l1: {}, loss_mse: {}, time: {}".format(
                    tested_batch * batch_size,
                    np.around([loss_l1.data[0]], decimals=8),
                    np.around([loss_mse.data[0]], decimals=8),
                    np.around([cur_time - pre_time], decimals=8),
                )
            )
            pre_time = cur_time

    losses_l1 = np.array(losses_l1)
    losses_mse = np.array(losses_mse)
    MAEs = np.array(MAEs)
    MAPEs = np.array(MAPEs)

    mean_l1 = np.mean(losses_l1) * max_speed
    std_l1 = np.std(losses_l1) * max_speed
    MAE_ = np.mean(MAEs) * max_speed
    MAPE_ = np.mean(MAPEs) * 100

    print("Tested: L1_mean: {}, L1_std: {}, MAE: {} MAPE: {}".format(mean_l1, std_l1, MAE_, MAPE_))

    all_labels = np.concatenate(all_labels, axis=0)
    all_outputs = np.concatenate(all_outputs, axis=0)
    all_inputs = np.concatenate(all_inputs,axis=0)

    return [losses_l1, losses_mse, mean_l1, std_l1, all_labels, all_outputs, all_inputs]

def plot_histograms(true_values, predicted_values, bins=50):
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.hist(true_values, bins=bins, alpha=0.7, label='True Values')
    plt.title('Histogram of True Values')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.hist(predicted_values, bins=bins, alpha=0.7, label='Predicted Values')
    plt.title('Histogram of Predicted Values')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.legend()

    plt.show()

# Example usage
# Assuming `test_dataloader` and `model` are already defined and loaded
max_speed = 100  # Example value, replace with actual max_speed
results = Test_Model(lgnet, test_dataloader, max_speed)
losses_l1, losses_mse, mean_l1, std_l1, all_labels, all_outputs, all_inputs = results

plot_histograms(all_labels.flatten(), all_outputs.flatten(), bins=50)
# Out:
# Tested: L1_mean: 3.365940600633621, L1_std: 0.15776865184307098, MAE: 3.365940600633621 MAPE: 6.567765772342682

# %%
print(all_labels.shape)
# Out:
# (640, 1, 323)

# %%
print(all_outputs.shape)
# Out:
# (640, 323)

# %%
print(all_inputs.shape)
# Out:
# (640, 6, 10, 323)

# %%
def plot_step_graph(true_values, predicted_values, input_values, time_index, id):
    true_values_time = np.append(input_values[time_index,0,:,id] ,true_values[time_index, id])
    predicted_values_time = np.append(input_values[time_index,0,:,id] ,predicted_values[time_index, id])
    num_dimensions = true_values_time.shape[0]

    indices = np.arange(num_dimensions)
    plt.plot(indices, predicted_values_time, linestyle='-', label='Predicted Values', color='r')
    plt.plot(indices, true_values_time, linestyle='-', label='input Values', color='b')

    plt.xlabel('Time')
    plt.ylabel('Value')
    plt.title(f'Input, True and Predicted Values at Time Index {time_index} and ID {id}')
    plt.legend()
    plt.grid(True)
    plt.show()

plot_step_graph(all_labels.squeeze(), all_outputs, all_inputs, 135, 56)

# %%
def plot_bar_graph(true_values, predicted_values, time_index):
    true_values_time = true_values[time_index, :]
    predicted_values_time = predicted_values[time_index, :]
    num_dimensions = true_values_time.shape[0]

    plt.figure(figsize=(12, 8))
    indices = np.arange(num_dimensions)
    width = 0.35

    plt.bar(indices, true_values_time, width, label='True Values')
    plt.bar(indices + width, predicted_values_time, width, label='Predicted Values')

    plt.xlabel('Dimension')
    plt.ylabel('Value')
    plt.title(f'True and Predicted Values at Time Index {time_index}')
    plt.legend()
    plt.show()

time_index_to_visualize = 0
plot_bar_graph(all_labels.squeeze(), all_outputs, time_index_to_visualize)

# %%
def plot_bar_graph(true_values, predicted_values, time_index):
    true_values_time = true_values[time_index, :]
    predicted_values_time = predicted_values[time_index, :]
    num_dimensions = true_values_time.shape[0]

    plt.figure(figsize=(12, 8))
    indices = np.arange(num_dimensions)

    plt.plot(indices, true_values_time, linestyle='-', label='True Values', color='b')
    plt.plot(indices, predicted_values_time, linestyle='-', label='Predicted Values', color='r')

    plt.xlabel('Dimension')
    plt.ylabel('Value')
    plt.title(f'True and Predicted Values at Time Index {time_index}')
    plt.legend()
    plt.grid(True)
    plt.show()

time_index_to_visualize = 0
plot_bar_graph(all_labels.squeeze(), all_outputs, time_index_to_visualize)

# %%
def calculate_mae_mape(true_values, predicted_values):
    mae_per_timestep = np.mean(np.abs(true_values - predicted_values), axis=0)
    mape_per_timestep = np.mean(np.abs((true_values - predicted_values) / true_values), axis=0) * 100

    return mae_per_timestep, mape_per_timestep

def find_extreme_indices(mae_per_timestep, mape_per_timestep):
    mae_min_index = np.argmin(mae_per_timestep)
    mae_max_index = np.argmax(mae_per_timestep)
    mape_min_index = np.argmin(mape_per_timestep)
    mape_max_index = np.argmax(mape_per_timestep)

    return mae_min_index, mae_max_index, mape_min_index, mape_max_index

# Example usage
# Assuming `all_labels` and `all_outputs` are obtained from the Test_Model function
all_labels = all_labels.squeeze()
all_outputs = all_outputs.squeeze()

mae_per_timestep, mape_per_timestep = calculate_mae_mape(all_labels, all_outputs)
mae_min_index, mae_max_index, mape_min_index, mape_max_index = find_extreme_indices(mae_per_timestep, mape_per_timestep)

# %%
def plot_min_graph(true_values, predicted_values, time_index):
    true_values_time = true_values[time_index, :]
    predicted_values_time = predicted_values[time_index, :]
    num_dimensions = true_values_time.shape[0]

    plt.figure(figsize=(12, 8))
    indices = np.arange(num_dimensions)

    plt.plot(indices, true_values_time, linestyle='-', label='True Values', color='b')
    plt.plot(indices, predicted_values_time, linestyle='-', label='Predicted Values', color='r')

    plt.xlabel('Dimension')
    plt.ylabel('Value')
    plt.title(f'True and Predicted Values at MAE MIN Index {time_index}: {mae_per_timestep[time_index]*100}')
    plt.legend()
    plt.show()

def plot_max_graph(true_values, predicted_values, time_index):
    true_values_time = true_values[time_index, :]
    predicted_values_time = predicted_values[time_index, :]
    num_dimensions = true_values_time.shape[0]

    plt.figure(figsize=(12, 8))
    indices = np.arange(num_dimensions)

    plt.plot(indices, true_values_time, linestyle='-', label='True Values', color='b')
    plt.plot(indices, predicted_values_time, linestyle='-', label='Predicted Values', color='r')

    plt.xlabel('Dimension')
    plt.ylabel('Value')
    plt.title(f'True and Predicted Values at MAE MAX Index {time_index}: {mae_per_timestep[time_index]*100}')
    plt.legend()
    plt.show()

# %%
plot_min_graph(all_labels.squeeze(), all_outputs, mae_min_index)
plot_max_graph(all_labels.squeeze(), all_outputs, mae_max_index)
